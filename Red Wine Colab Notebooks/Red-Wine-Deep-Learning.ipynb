# %% [markdown]
# Import Libraries

# %%
# !pip install keras-tuner
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import pandas as pd
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
url = "/content/gdrive/My Drive/Uni/Bootcamp/Bootcamp1/Project_4/winequality-red.csv"
chem_df = pd.read_csv(url)
chem_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
chem_df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
chem_df['quality'] = pd.cut(chem_df['quality'], bins = bins, labels = group_names)
label_quality = LabelEncoder()
chem_df['quality'] = label_quality.fit_transform(chem_df['quality'])
chem_df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
# Remove quality target from features data
y = chem_df.quality.values
X = chem_df.drop(columns="quality").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=11))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customise metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 38/38 [==============================] - 5s 5ms/step - loss: 0.6789 - accuracy: 0.5822
# Epoch 2/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.5060 - accuracy: 0.8641
# Epoch 3/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.3859 - accuracy: 0.8641
# Epoch 4/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.3330 - accuracy: 0.8641
# Epoch 5/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.3029 - accuracy: 0.8641
# Epoch 6/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2834 - accuracy: 0.8641
# Epoch 7/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.2740 - accuracy: 0.8649
# Epoch 8/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2668 - accuracy: 0.8641
# Epoch 9/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.2650 - accuracy: 0.8682
# Epoch 10/100
# ...
