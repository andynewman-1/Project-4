# %% [markdown]
# Import Libraries

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import pandas as pd
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
url = "/content/gdrive/My Drive/Uni/Bootcamp/Bootcamp1/Project_4/winequality-red.csv"
chem_df = pd.read_csv(url)
chem_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
chem_df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
chem_df['quality'] = pd.cut(chem_df['quality'], bins = bins, labels = group_names)
label_quality = LabelEncoder()
chem_df['quality'] = label_quality.fit_transform(chem_df['quality'])
chem_df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
# Remove quality target from features data
y = chem_df.quality.values
X = chem_df.drop(columns="quality").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=11))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customise metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.6020 - accuracy: 0.7148
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4291 - accuracy: 0.8599
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3639 - accuracy: 0.8641
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8649
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 0.8649
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3025 - accuracy: 0.8666
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2937 - accuracy: 0.8649
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 0.8707
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2838 - accuracy: 0.8741
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2800 - accuracy: 0.8741
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 0.8799
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.8832
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2732 - accuracy: 0.8882
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.8882
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.8857
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8932
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.8866
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.8874
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8841
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.8866
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2628 - accuracy: 0.8866
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8874
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.8857
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.8857
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2586 - accuracy: 0.8857
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2586 - accuracy: 0.8866
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8866
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.8849
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.8866
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2545 - accuracy: 0.8891
# Epoch 31/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2537 - accuracy: 0.8882
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.8849
# Epoch 33/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2521 - accuracy: 0.8832
# Epoch 34/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.8916
# Epoch 35/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.8857
# Epoch 36/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8857
# Epoch 37/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.8857
# Epoch 38/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.8874
# Epoch 39/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.8866
# Epoch 40/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.8899
# Epoch 41/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 0.8899
# Epoch 42/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8849
# Epoch 43/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.8857
# Epoch 44/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.8882
# Epoch 45/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2427 - accuracy: 0.8891
# Epoch 46/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2422 - accuracy: 0.8874
# Epoch 47/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.8882
# Epoch 48/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.8882
# Epoch 49/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.8857
# Epoch 50/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.8866
# 13/13 - 0s - loss: 0.2925 - accuracy: 0.8875 - 149ms/epoch - 11ms/step
# Loss: 0.29246407747268677, Accuracy: 0.887499988079071
