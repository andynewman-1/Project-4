# %% [markdown]
# Import Libraries

# %%
# !pip install keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import pandas as pd
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
url = "/content/gdrive/My Drive/Uni/Bootcamp/Bootcamp1/Project_4/winequality-white.csv"
wchem_df = pd.read_csv(url)
wchem_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wchem_df.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
bins = (2, 6.5, 9)
group_names = ['bad', 'good']
wchem_df['quality'] = pd.cut(wchem_df['quality'], bins = bins, labels = group_names)
label_quality = LabelEncoder()
wchem_df['quality'] = label_quality.fit_transform(wchem_df['quality'])
wchem_df['quality'].value_counts()
# Out:
# 0    3838
# 1    1060
# Name: quality, dtype: int64

# %%
# Remove quality target from features data
y = wchem_df.quality.values
X = wchem_df.drop(columns="quality").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=11))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customise metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 115/115 [==============================] - 2s 3ms/step - loss: 0.6601 - accuracy: 0.6077
# Epoch 2/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.4532 - accuracy: 0.8021
# Epoch 3/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4218 - accuracy: 0.8102
# Epoch 4/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8151
# Epoch 5/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3998 - accuracy: 0.8135
# Epoch 6/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8198
# Epoch 7/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8127
# Epoch 8/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3844 - accuracy: 0.8179
# Epoch 9/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8162
# Epoch 10/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8211
# Epoch 11/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.8252
# Epoch 12/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3734 - accuracy: 0.8249
# Epoch 13/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8255
# Epoch 14/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8277
# Epoch 15/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3690 - accuracy: 0.8258
# Epoch 16/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3674 - accuracy: 0.8277
# Epoch 17/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8271
# Epoch 18/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3651 - accuracy: 0.8271
# Epoch 19/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.8244
# Epoch 20/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3625 - accuracy: 0.8279
# Epoch 21/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8258
# Epoch 22/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3611 - accuracy: 0.8285
# Epoch 23/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3606 - accuracy: 0.8244
# Epoch 24/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3598 - accuracy: 0.8279
# Epoch 25/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3582 - accuracy: 0.8252
# Epoch 26/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8288
# Epoch 27/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8222
# Epoch 28/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8263
# Epoch 29/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8233
# Epoch 30/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3542 - accuracy: 0.8271
# Epoch 31/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8282
# Epoch 32/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.8252
# Epoch 33/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3517 - accuracy: 0.8277
# Epoch 34/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.8274
# Epoch 35/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8274
# Epoch 36/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8285
# Epoch 37/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8285
# Epoch 38/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8285
# Epoch 39/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8315
# Epoch 40/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3469 - accuracy: 0.8298
# Epoch 41/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3465 - accuracy: 0.8293
# Epoch 42/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3459 - accuracy: 0.8347
# Epoch 43/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3457 - accuracy: 0.8347
# Epoch 44/50
# 115/115 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8353
# Epoch 45/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8350
# Epoch 46/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3424 - accuracy: 0.8334
# Epoch 47/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3426 - accuracy: 0.8361
# Epoch 48/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.8361
# Epoch 49/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3403 - accuracy: 0.8380
# Epoch 50/50
# 115/115 [==============================] - 0s 3ms/step - loss: 0.3405 - accuracy: 0.8364
# 39/39 - 0s - loss: 0.3760 - accuracy: 0.8114 - 221ms/epoch - 6ms/step
# Loss: 0.3760393261909485, Accuracy: 0.8114285469055176
